# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('canada.csv')
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
X=df[['year']]
y=df['per capita income (US$)']
X.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
y.head()
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# Name: per capita income (US$), dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
model= LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(len(X_test))
# Out:
# 5

# %%
y_pred=model.predict(X_test)
print(y_pred)
# Out:
# [38119.46807129 31451.8003675  22283.75727479  5614.58801531
#  17283.00649694]

# %%
model.predict([[2022]])
# Out:
# C:\Users\ACER\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([43120.21884913])

# %%
# %matplotlib inline
plt.xlabel('year',color='Blue')
plt.ylabel('PCI US($)',color='Blue')
plt.scatter(X,y, color='red', marker='+')
plt.plot(X,model.predict(X),color='blue')
